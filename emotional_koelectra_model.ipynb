# %%
import pandas as pd
import torch
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, ElectraForSequenceClassification, AdamW
from sklearn.model_selection import train_test_split
from transformers import ElectraModel, ElectraTokenizer
from tqdm.notebook import tqdm
import torch.nn as nn
import torch.nn.init as init
from sklearn.metrics import f1_score
data = pd.read_csv('/home/kdt-admin/cleaned_data.csv').dropna(axis=0)
data.reset_index(drop=True, inplace=True)

# %%
data['문장'].nunique(), data['감정'].nunique()
# Out:
# (173247, 6)

# %%
data.drop_duplicates(subset=['문장'], inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data.loc[(data['감정'] == "중립"), '감정'] = 0  
data.loc[(data['감정'] == "슬픔"), '감정'] = 1  
data.loc[(data['감정'] == "분노"), '감정'] = 2  
data.loc[(data['감정'] == "불안"), '감정'] = 3  
data.loc[(data['감정'] == "행복"), '감정'] = 4  
data.loc[(data['감정'] == "당황"), '감정'] = 5

# %%
data
# Out:
#        감정                                                 문장
# 0       2  일은 왜 해도 해도 끝이 없을까 ? 화가 난다 . 그냥 내가 해결하는 게 나아 . ...
# 1       2  이번 달에 또 급여가 깎였어 ! 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나...
# 2       2  회사에 신입이 들어왔는데 말투가 거슬려 . 그런 애를 매일 봐야 한다고 생각하니까 ...
# 3       2  직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜 . 일도 많은 데 정말 분하고...
# 4       2  얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나 . 상사인 나에게...
# ...    ..                                                ...
# 173242  5                                      오마이갓 믿을 수가 없어
# 173243  5                                     하느님 이거 너무 힘들어요
# 173244  5                                              엄청난 쇼
# 173245  5                                       오머나 정말 놀랐습니다
# 173246  5                               이게 무슨 일인지 이해가 안 돼요당황
#
# [173247 rows x 2 columns]

# %%
# GPU 사용
device = torch.device("cuda")

# %%
class CsixDataset(Dataset):
  
  def __init__(self, data):
    self.dataset = data 
    # 중복제거
    self.dataset.drop_duplicates(subset=['문장'], inplace=True)
    self.tokenizer =  AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")
    #"monologg/koelectra-small-v3-discriminator" small data
    #"monologg/koelectra-base-v3-discriminator" big data

    print(self.dataset.describe())
  
  def __len__(self):
    return len(self.dataset)
  
  def __getitem__(self, idx):
    row = self.dataset.iloc[idx, 0:2].values
    text = row[1]
    y = row[0]

    inputs = self.tokenizer(
        text, 
        return_tensors='pt',
        truncation=True,
        max_length=75,
        pad_to_max_length=True,
        add_special_tokens=True
        )
    
    input_ids = inputs['input_ids'][0]
    attention_mask = inputs['attention_mask'][0]

    return input_ids, attention_mask, y

# %%
# 데이터셋을 트레이닝과 테스트로 나눔
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# 트레이닝 데이터셋과 테스트 데이터셋 클래스 인스턴스 생성
train_dataset = CsixDataset(train_data)
test_dataset = CsixDataset(test_data)
# Out:
#             감정                             문장
# count   138597                         138597
# unique       6                         138597
# top          0  어머 이게 무슨 일이에요 저는 뭐가 잘못된 것 같아요
# freq     36182                              1
#            감정       문장
# count   34650    34650
# unique      6    34650
# top         0  네 . 도련님
# freq     9016        1

# %%
num_classes = 6  # 클래스 수에 맞게 설정
model = ElectraForSequenceClassification.from_pretrained("monologg/koelectra-base-v3-discriminator", num_labels=num_classes)
# Out:
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
text, attention_mask, y = train_dataset[0]
model(text.unsqueeze(0), attention_mask=attention_mask.unsqueeze(0))
# Out:
# /home/kdt-admin/miniconda3/envs/kti/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2688: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# SequenceClassifierOutput(loss=None, logits=tensor([[ 0.0464,  0.0233, -0.0597, -0.0039, -0.0554, -0.0641]],
#        grad_fn=<AddmmBackward0>), hidden_states=None, attentions=None)

# %%
# 모델 레이어 보기
model = model.to(device)

# %%
epochs = 4
batch_size = 16

# %%
optimizer = AdamW(model.parameters(), lr=5e-6)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)
# Out:
# /home/kdt-admin/miniconda3/envs/kti/lib/python3.10/site-packages/transformers/optimization.py:457: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

for epoch in range(epochs):
    # Training
    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    
    for input_ids_batch, attention_masks_batch, y_batch in tqdm(train_loader):
        optimizer.zero_grad()
        y_batch = y_batch.to(device)
        y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
        loss = F.cross_entropy(y_pred, y_batch)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        _, predicted = torch.max(y_pred, 1)
        correct_train += (predicted == y_batch).sum().item()
        total_train += len(y_batch)
        
        # Print batch accuracy
        batch_accuracy = correct_train / total_train
        print(f"Epoch {epoch+1}/{epochs}, Batch Accuracy: {batch_accuracy:.4f}")

    train_losses.append(train_loss / len(train_loader))
    train_accuracy = correct_train / total_train
    train_accuracies.append(train_accuracy)

    # Testing
    model.eval()
    test_loss = 0.0
    correct_test = 0
    total_test = 0
    
    with torch.no_grad():
        for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
            y_batch = y_batch.to(device)
            y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
            loss = F.cross_entropy(y_pred, y_batch)

            test_loss += loss.item()

            _, predicted = torch.max(y_pred, 1)
            correct_test += (predicted == y_batch).sum().item()
            total_test += len(y_batch)
    
    test_losses.append(test_loss / len(test_loader))
    test_accuracy = correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_losses[-1]:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {test_losses[-1]:.4f}, Test Accuracy: {test_accuracy:.4f}")
        
    # Calculate F1 score
    
    predicted_labels = []
    true_labels = []

    with torch.no_grad():
        for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
            y_batch = y_batch.to(device)
            y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
            _, predicted = torch.max(y_pred, 1)

            predicted_labels.extend(predicted.cpu().numpy())
            true_labels.extend(y_batch.cpu().numpy())

    f1 = f1_score(true_labels, predicted_labels, average='weighted')
    print("F1 Score:", f1)
# Out:
#   0%|          | 0/8663 [00:00<?, ?it/s]
# /home/kdt-admin/miniconda3/envs/kti/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2688: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Epoch 1/4, Batch Accuracy: 0.2500
# Epoch 1/4, Batch Accuracy: 0.2500
# Epoch 1/4, Batch Accuracy: 0.2500
# Epoch 1/4, Batch Accuracy: 0.2500
# Epoch 1/4, Batch Accuracy: 0.2625
# Epoch 1/4, Batch Accuracy: 0.2812
# Epoch 1/4, Batch Accuracy: 0.2411
# Epoch 1/4, Batch Accuracy: 0.2500
# Epoch 1/4, Batch Accuracy: 0.2361
# Epoch 1/4, Batch Accuracy: 0.2437
# Epoch 1/4, Batch Accuracy: 0.2386
# Epoch 1/4, Batch Accuracy: 0.2344
# Epoch 1/4, Batch Accuracy: 0.2260
# Epoch 1/4, Batch Accuracy: 0.2366
# Epoch 1/4, Batch Accuracy: 0.2333
# Epoch 1/4, Batch Accuracy: 0.2344
# Epoch 1/4, Batch Accuracy: 0.2316
# Epoch 1/4, Batch Accuracy: 0.2326
# Epoch 1/4, Batch Accuracy: 0.2401
# Epoch 1/4, Batch Accuracy: 0.2406
# Epoch 1/4, Batch Accuracy: 0.2411
# Epoch 1/4, Batch Accuracy: 0.2386
# Epoch 1/4, Batch Accuracy: 0.2418
# Epoch 1/4, Batch Accuracy: 0.2422
# Epoch 1/4, Batch Accuracy: 0.2375
# Epoch 1/4, Batch Accuracy: 0.2404
# Epoch 1/4, Batch Accuracy: 0.2384
# Epoch 1/4, Batch Accuracy: 0.2388
# Epoch 1/4, Batch Accuracy: 0.2349
# Epoch 1/4, Batch Accuracy: 0.2333
# Epoch 1/4, Batch Accuracy: 0.2319
# Epoch 1/4, Batch Accuracy: 0.2383
# Epoch 1/4, Batch Accuracy: 0.2386
# Epoch 1/4, Batch Accuracy: 0.2371
# Epoch 1/4, Batch Accuracy: 0.2339
# Epoch 1/4, Batch Accuracy: 0.2326
# Epoch 1/4, Batch Accuracy: 0.2297
# Epoch 1/4, Batch Accuracy: 0.2336
# Epoch 1/4, Batch Accuracy: 0.2420
# Epoch 1/4, Batch Accuracy: 0.2391
# Epoch 1/4, Batch Accuracy: 0.2439
# Epoch 1/4, Batch Accuracy: 0.2411
# Epoch 1/4, Batch Accuracy: 0.2442
# Epoch 1/4, Batch Accuracy: 0.2443
# Epoch 1/4, Batch Accuracy: 0.2458
# Epoch 1/4, Batch Accuracy: 0.2446
# Epoch 1/4, Batch Accuracy: 0.2434
# Epoch 1/4, Batch Accuracy: 0.2422
# Epoch 1/4, Batch Accuracy: 0.2436
# Epoch 1/4, Batch Accuracy: 0.2412
# Epoch 1/4, Batch Accuracy: 0.2426
# Epoch 1/4, Batch Accuracy: 0.2428
# Epoch 1/4, Batch Accuracy: 0.2406
# Epoch 1/4, Batch Accuracy: 0.2431
# Epoch 1/4, Batch Accuracy: 0.2432
# Epoch 1/4, Batch Accuracy: 0.2433
# Epoch 1/4, Batch Accuracy: 0.2478
# Epoch 1/4, Batch Accuracy: 0.2478
# Epoch 1/4, Batch Accuracy: 0.2468
# Epoch 1/4, Batch Accuracy: 0.2469
# Epoch 1/4, Batch Accuracy: 0.2449
# Epoch 1/4, Batch Accuracy: 0.2450
# Epoch 1/4, Batch Accuracy: 0.2460
# Epoch 1/4, Batch Accuracy: 0.2441
# Epoch 1/4, Batch Accuracy: 0.2452
# Epoch 1/4, Batch Accuracy: 0.2462
# Epoch 1/4, Batch Accuracy: 0.2463
# Epoch 1/4, Batch Accuracy: 0.2454
# Epoch 1/4, Batch Accuracy: 0.2446
# Epoch 1/4, Batch Accuracy: 0.2446
# Epoch 1/4, Batch Accuracy: 0.2474
# Epoch 1/4, Batch Accuracy: 0.2474
# Epoch 1/4, Batch Accuracy: 0.2466
# Epoch 1/4, Batch Accuracy: 0.2483
# Epoch 1/4, Batch Accuracy: 0.2525
# Epoch 1/4, Batch Accuracy: 0.2541
# Epoch 1/4, Batch Accuracy: 0.2573
# Epoch 1/4, Batch Accuracy: 0.2572
# Epoch 1/4, Batch Accuracy: 0.2603
# Epoch 1/4, Batch Accuracy: 0.2609
# Epoch 1/4, Batch Accuracy: 0.2616
# Epoch 1/4, Batch Accuracy: 0.2599
# Epoch 1/4, Batch Accuracy: 0.2613
# Epoch 1/4, Batch Accuracy: 0.2649
# Epoch 1/4, Batch Accuracy: 0.2669
# Epoch 1/4, Batch Accuracy: 0.2667
# Epoch 1/4, Batch Accuracy: 0.2651
# Epoch 1/4, Batch Accuracy: 0.2649
# Epoch 1/4, Batch Accuracy: 0.2662
# Epoch 1/4, Batch Accuracy: 0.2674
# Epoch 1/4, Batch Accuracy: 0.2672
# Epoch 1/4, Batch Accuracy: 0.2697
# Epoch 1/4, Batch Accuracy: 0.2702
# Epoch 1/4, Batch Accuracy: 0.2713
# Epoch 1/4, Batch Accuracy: 0.2717
# Epoch 1/4, Batch Accuracy: 0.2721
# Epoch 1/4, Batch Accuracy: 0.2719
# Epoch 1/4, Batch Accuracy: 0.2704
# Epoch 1/4, Batch Accuracy: 0.2708
# Epoch 1/4, Batch Accuracy: 0.2719
# Epoch 1/4, Batch Accuracy: 0.2723
# Epoch 1/4, Batch Accuracy: 0.2739
# Epoch 1/4, Batch Accuracy: 0.2755
# Epoch 1/4, Batch Accuracy: 0.2776
# Epoch 1/4, Batch Accuracy: 0.2798
# Epoch 1/4, Batch Accuracy: 0.2801
# Epoch 1/4, Batch Accuracy: 0.2804
# Epoch 1/4, Batch Accuracy: 0.2812
# Epoch 1/4, Batch Accuracy: 0.2815
# Epoch 1/4, Batch Accuracy: 0.2830
# Epoch 1/4, Batch Accuracy: 0.2855
# Epoch 1/4, Batch Accuracy: 0.2863
# Epoch 1/4, Batch Accuracy: 0.2882
# Epoch 1/4, Batch Accuracy: 0.2873
# Epoch 1/4, Batch Accuracy: 0.2880
# Epoch 1/4, Batch Accuracy: 0.2888
# Epoch 1/4, Batch Accuracy: 0.2895
# Epoch 1/4, Batch Accuracy: 0.2908
# Epoch 1/4, Batch Accuracy: 0.2915
# Epoch 1/4, Batch Accuracy: 0.2917
# Epoch 1/4, Batch Accuracy: 0.2918
# Epoch 1/4, Batch Accuracy: 0.2925
# Epoch 1/4, Batch Accuracy: 0.2927
# Epoch 1/4, Batch Accuracy: 0.2939
# Epoch 1/4, Batch Accuracy: 0.2945
# Epoch 1/4, Batch Accuracy: 0.2937
# Epoch 1/4, Batch Accuracy: 0.2948
# Epoch 1/4, Batch Accuracy: 0.2944
# Epoch 1/4, Batch Accuracy: 0.2951
# Epoch 1/4, Batch Accuracy: 0.2971
# Epoch 1/4, Batch Accuracy: 0.2982
# Epoch 1/4, Batch Accuracy: 0.2988
# Epoch 1/4, Batch Accuracy: 0.3003
# Epoch 1/4, Batch Accuracy: 0.3008
# Epoch 1/4, Batch Accuracy: 0.3028
# Epoch 1/4, Batch Accuracy: 0.3019
# Epoch 1/4, Batch Accuracy: 0.3020
# Epoch 1/4, Batch Accuracy: 0.3021
# Epoch 1/4, Batch Accuracy: 0.3031
# Epoch 1/4, Batch Accuracy: 0.3054
# Epoch 1/4, Batch Accuracy: 0.3054
# Epoch 1/4, Batch Accuracy: 0.3072
# Epoch 1/4, Batch Accuracy: 0.3073
# Epoch 1/4, Batch Accuracy: 0.3069
# Epoch 1/4, Batch Accuracy: 0.3065
# Epoch 1/4, Batch Accuracy: 0.3065
# Epoch 1/4, Batch Accuracy: 0.3057
# Epoch 1/4, Batch Accuracy: 0.3074
# Epoch 1/4, Batch Accuracy: 0.3096
# Epoch 1/4, Batch Accuracy: 0.3104
# Epoch 1/4, Batch Accuracy: 0.3117
# Epoch 1/4, Batch Accuracy: 0.3133
# Epoch 1/4, Batch Accuracy: 0.3141
# Epoch 1/4, Batch Accuracy: 0.3145
# Epoch 1/4, Batch Accuracy: 0.3153
# Epoch 1/4, Batch Accuracy: 0.3177
# Epoch 1/4, Batch Accuracy: 0.3189
# Epoch 1/4, Batch Accuracy: 0.3184
# Epoch 1/4, Batch Accuracy: 0.3200
# Epoch 1/4, Batch Accuracy: 0.3219
# Epoch 1/4, Batch Accuracy: 0.3218
# Epoch 1/4, Batch Accuracy: 0.3218
# Epoch 1/4, Batch Accuracy: 0.3217
# Epoch 1/4, Batch Accuracy: 0.3220
# Epoch 1/4, Batch Accuracy: 0.3223
# Epoch 1/4, Batch Accuracy: 0.3234
# Epoch 1/4, Batch Accuracy: 0.3241
# Epoch 1/4, Batch Accuracy: 0.3255
# Epoch 1/4, Batch Accuracy: 0.3251
# Epoch 1/4, Batch Accuracy: 0.3257
# Epoch 1/4, Batch Accuracy: 0.3271
# Epoch 1/4, Batch Accuracy: 0.3259
# Epoch 1/4, Batch Accuracy: 0.3266
# Epoch 1/4, Batch Accuracy: 0.3258
# Epoch 1/4, Batch Accuracy: 0.3257
# Epoch 1/4, Batch Accuracy: 0.3263
# Epoch 1/4, Batch Accuracy: 0.3263
# Epoch 1/4, Batch Accuracy: 0.3269
# Epoch 1/4, Batch Accuracy: 0.3275
# Epoch 1/4, Batch Accuracy: 0.3274
# Epoch 1/4, Batch Accuracy: 0.3291
# Epoch 1/4, Batch Accuracy: 0.3310
# Epoch 1/4, Batch Accuracy: 0.3313
# Epoch 1/4, Batch Accuracy: 0.3332
# Epoch 1/4, Batch Accuracy: 0.3341
# Epoch 1/4, Batch Accuracy: 0.3347
# Epoch 1/4, Batch Accuracy: 0.3356
# Epoch 1/4, Batch Accuracy: 0.3361
# Epoch 1/4, Batch Accuracy: 0.3370
# Epoch 1/4, Batch Accuracy: 0.3385
# Epoch 1/4, Batch Accuracy: 0.3406
# Epoch 1/4, Batch Accuracy: 0.3418
# Epoch 1/4, Batch Accuracy: 0.3423
# Epoch 1/4, Batch Accuracy: 0.3434
# Epoch 1/4, Batch Accuracy: 0.3433
# Epoch 1/4, Batch Accuracy: 0.3447
# Epoch 1/4, Batch Accuracy: 0.3449
# Epoch 1/4, Batch Accuracy: 0.3453
# Epoch 1/4, Batch Accuracy: 0.3467
# Epoch 1/4, Batch Accuracy: 0.3475
# Epoch 1/4, Batch Accuracy: 0.3476
# Epoch 1/4, Batch Accuracy: 0.3481
# Epoch 1/4, Batch Accuracy: 0.3485
# Epoch 1/4, Batch Accuracy: 0.3487
# Epoch 1/4, Batch Accuracy: 0.3497
# Epoch 1/4, Batch Accuracy: 0.3504
# Epoch 1/4, Batch Accuracy: 0.3502
# Epoch 1/4, Batch Accuracy: 0.3507
# Epoch 1/4, Batch Accuracy: 0.3511
# Epoch 1/4, Batch Accuracy: 0.3512
# Epoch 1/4, Batch Accuracy: 0.3510
# Epoch 1/4, Batch Accuracy: 0.3517
# Epoch 1/4, Batch Accuracy: 0.3515
# Epoch 1/4, Batch Accuracy: 0.3519
# Epoch 1/4, Batch Accuracy: 0.3523
# Epoch 1/4, Batch Accuracy: 0.3530
# Epoch 1/4, Batch Accuracy: 0.3540
# Epoch 1/4, Batch Accuracy: 0.3538
# Epoch 1/4, Batch Accuracy: 0.3539
# Epoch 1/4, Batch Accuracy: 0.3540
# Epoch 1/4, Batch Accuracy: 0.3541
# Epoch 1/4, Batch Accuracy: 0.3544
# Epoch 1/4, Batch Accuracy: 0.3557
# Epoch 1/4, Batch Accuracy: 0.3569
# Epoch 1/4, Batch Accuracy: 0.3564
# Epoch 1/4, Batch Accuracy: 0.3576
# Epoch 1/4, Batch Accuracy: 0.3577
# Epoch 1/4, Batch Accuracy: 0.3586
# Epoch 1/4, Batch Accuracy: 0.3589
# Epoch 1/4, Batch Accuracy: 0.3595
# Epoch 1/4, Batch Accuracy: 0.3596
# Epoch 1/4, Batch Accuracy: 0.3602
# Epoch 1/4, Batch Accuracy: 0.3613
# Epoch 1/4, Batch Accuracy: 0.3608
# Epoch 1/4, Batch Accuracy: 0.3612
# Epoch 1/4, Batch Accuracy: 0.3628
# Epoch 1/4, Batch Accuracy: 0.3634
# Epoch 1/4, Batch Accuracy: 0.3629
# Epoch 1/4, Batch Accuracy: 0.3632
# Epoch 1/4, Batch Accuracy: 0.3638
# Epoch 1/4, Batch Accuracy: 0.3638
# Epoch 1/4, Batch Accuracy: 0.3647
# Epoch 1/4, Batch Accuracy: 0.3645
# Epoch 1/4, Batch Accuracy: 0.3645
# Epoch 1/4, Batch Accuracy: 0.3648
# Epoch 1/4, Batch Accuracy: 0.3659
# Epoch 1/4, Batch Accuracy: 0.3661
# Epoch 1/4, Batch Accuracy: 0.3657
# Epoch 1/4, Batch Accuracy: 0.3657
# Epoch 1/4, Batch Accuracy: 0.3658
# Epoch 1/4, Batch Accuracy: 0.3660
# Epoch 1/4, Batch Accuracy: 0.3658
# Epoch 1/4, Batch Accuracy: 0.3661
# Epoch 1/4, Batch Accuracy: 0.3669
# Epoch 1/4, Batch Accuracy: 0.3672
# Epoch 1/4, Batch Accuracy: 0.3674
# Epoch 1/4, Batch Accuracy: 0.3675
# Epoch 1/4, Batch Accuracy: 0.3677
# Epoch 1/4, Batch Accuracy: 0.3682
# Epoch 1/4, Batch Accuracy: 0.3695
# Epoch 1/4, Batch Accuracy: 0.3702
# Epoch 1/4, Batch Accuracy: 0.3712
# Epoch 1/4, Batch Accuracy: 0.3717
# Epoch 1/4, Batch Accuracy: 0.3724
# Epoch 1/4, Batch Accuracy: 0.3736
# Epoch 1/4, Batch Accuracy: 0.3738
# Epoch 1/4, Batch Accuracy: 0.3745
# Epoch 1/4, Batch Accuracy: 0.3752
# Epoch 1/4, Batch Accuracy: 0.3762
# Epoch 1/4, Batch Accuracy: 0.3759
# Epoch 1/4, Batch Accuracy: 0.3759
# Epoch 1/4, Batch Accuracy: 0.3757
# Epoch 1/4, Batch Accuracy: 0.3761
# Epoch 1/4, Batch Accuracy: 0.3757
# Epoch 1/4, Batch Accuracy: 0.3764
# Epoch 1/4, Batch Accuracy: 0.3759
# Epoch 1/4, Batch Accuracy: 0.3757
# Epoch 1/4, Batch Accuracy: 0.3761
# Epoch 1/4, Batch Accuracy: 0.3772
# Epoch 1/4, Batch Accuracy: 0.3779
# Epoch 1/4, Batch Accuracy: 0.3781
# Epoch 1/4, Batch Accuracy: 0.3785
# Epoch 1/4, Batch Accuracy: 0.3792
# Epoch 1/4, Batch Accuracy: 0.3792
# Epoch 1/4, Batch Accuracy: 0.3800
# Epoch 1/4, Batch Accuracy: 0.3809
# Epoch 1/4, Batch Accuracy: 0.3815
# Epoch 1/4, Batch Accuracy: 0.3824
# Epoch 1/4, Batch Accuracy: 0.3832
# Epoch 1/4, Batch Accuracy: 0.3841
# Epoch 1/4, Batch Accuracy: 0.3847
# Epoch 1/4, Batch Accuracy: 0.3848
# Epoch 1/4, Batch Accuracy: 0.3857
# Epoch 1/4, Batch Accuracy: 0.3858
# Epoch 1/4, Batch Accuracy: 0.3867
# Epoch 1/4, Batch Accuracy: 0.3870
# Epoch 1/4, Batch Accuracy: 0.3880
# Epoch 1/4, Batch Accuracy: 0.3880
# Epoch 1/4, Batch Accuracy: 0.3878
# Epoch 1/4, Batch Accuracy: 0.3879
# Epoch 1/4, Batch Accuracy: 0.3889
# Epoch 1/4, Batch Accuracy: 0.3891
# Epoch 1/4, Batch Accuracy: 0.3901
# Epoch 1/4, Batch Accuracy: 0.3910
# Epoch 1/4, Batch Accuracy: 0.3918
# Epoch 1/4, Batch Accuracy: 0.3920
# Epoch 1/4, Batch Accuracy: 0.3925
# Epoch 1/4, Batch Accuracy: 0.3933
# Epoch 1/4, Batch Accuracy: 0.3938
# Epoch 1/4, Batch Accuracy: 0.3948
# Epoch 1/4, Batch Accuracy: 0.3953
# Epoch 1/4, Batch Accuracy: 0.3956
# Epoch 1/4, Batch Accuracy: 0.3960
# Epoch 1/4, Batch Accuracy: 0.3965
# Epoch 1/4, Batch Accuracy: 0.3966
# Epoch 1/4, Batch Accuracy: 0.3972
# Epoch 1/4, Batch Accuracy: 0.3975
# Epoch 1/4, Batch Accuracy: 0.3976
# Epoch 1/4, Batch Accuracy: 0.3985
# Epoch 1/4, Batch Accuracy: 0.3990
# Epoch 1/4, Batch Accuracy: 0.3986
# Epoch 1/4, Batch Accuracy: 0.3987
# Epoch 1/4, Batch Accuracy: 0.3990
# Epoch 1/4, Batch Accuracy: 0.3999
# Epoch 1/4, Batch Accuracy: 0.3996
# Epoch 1/4, Batch Accuracy: 0.4003
# Epoch 1/4, Batch Accuracy: 0.4008
# Epoch 1/4, Batch Accuracy: 0.4011
# Epoch 1/4, Batch Accuracy: 0.4006
# Epoch 1/4, Batch Accuracy: 0.4009
# Epoch 1/4, Batch Accuracy: 0.4009
# Epoch 1/4, Batch Accuracy: 0.4012
# Epoch 1/4, Batch Accuracy: 0.4017
# Epoch 1/4, Batch Accuracy: 0.4025
# Epoch 1/4, Batch Accuracy: 0.4028
# Epoch 1/4, Batch Accuracy: 0.4033
# Epoch 1/4, Batch Accuracy: 0.4041
# Epoch 1/4, Batch Accuracy: 0.4044
# Epoch 1/4, Batch Accuracy: 0.4047
# Epoch 1/4, Batch Accuracy: 0.4048
# Epoch 1/4, Batch Accuracy: 0.4051
# Epoch 1/4, Batch Accuracy: 0.4055
# Epoch 1/4, Batch Accuracy: 0.4058
# Epoch 1/4, Batch Accuracy: 0.4061
# Epoch 1/4, Batch Accuracy: 0.4063
# Epoch 1/4, Batch Accuracy: 0.4066
# Epoch 1/4, Batch Accuracy: 0.4071
# Epoch 1/4, Batch Accuracy: 0.4080
# Epoch 1/4, Batch Accuracy: 0.4090
# Epoch 1/4, Batch Accuracy: 0.4091
# Epoch 1/4, Batch Accuracy: 0.4097
# Epoch 1/4, Batch Accuracy: 0.4103
# Epoch 1/4, Batch Accuracy: 0.4099
# Epoch 1/4, Batch Accuracy: 0.4105
# Epoch 1/4, Batch Accuracy: 0.4107
# Epoch 1/4, Batch Accuracy: 0.4106
# Epoch 1/4, Batch Accuracy: 0.4114
# Epoch 1/4, Batch Accuracy: 0.4117
# Epoch 1/4, Batch Accuracy: 0.4123
# Epoch 1/4, Batch Accuracy: 0.4123
# Epoch 1/4, Batch Accuracy: 0.4126
# Epoch 1/4, Batch Accuracy: 0.4132
# Epoch 1/4, Batch Accuracy: 0.4131
# Epoch 1/4, Batch Accuracy: 0.4129
# Epoch 1/4, Batch Accuracy: 0.4137
# Epoch 1/4, Batch Accuracy: 0.4143
# Epoch 1/4, Batch Accuracy: 0.4138
# Epoch 1/4, Batch Accuracy: 0.4139
# Epoch 1/4, Batch Accuracy: 0.4141
# Epoch 1/4, Batch Accuracy: 0.4139
# Epoch 1/4, Batch Accuracy: 0.4141
# Epoch 1/4, Batch Accuracy: 0.4147
# Epoch 1/4, Batch Accuracy: 0.4150
# Epoch 1/4, Batch Accuracy: 0.4151
# Epoch 1/4, Batch Accuracy: 0.4157
# Epoch 1/4, Batch Accuracy: 0.4161
# Epoch 1/4, Batch Accuracy: 0.4164
# Epoch 1/4, Batch Accuracy: 0.4172
# Epoch 1/4, Batch Accuracy: 0.4172
# Epoch 1/4, Batch Accuracy: 0.4171
# Epoch 1/4, Batch Accuracy: 0.4178
# Epoch 1/4, Batch Accuracy: 0.4182
# Epoch 1/4, Batch Accuracy: 0.4186
# Epoch 1/4, Batch Accuracy: 0.4183
# Epoch 1/4, Batch Accuracy: 0.4192
# Epoch 1/4, Batch Accuracy: 0.4200
# Epoch 1/4, Batch Accuracy: 0.4204
# Epoch 1/4, Batch Accuracy: 0.4209
# Epoch 1/4, Batch Accuracy: 0.4213
# Epoch 1/4, Batch Accuracy: 0.4215
# Epoch 1/4, Batch Accuracy: 0.4212
# Epoch 1/4, Batch Accuracy: 0.4216
# Epoch 1/4, Batch Accuracy: 0.4221
# Epoch 1/4, Batch Accuracy: 0.4226
# Epoch 1/4, Batch Accuracy: 0.4228
# Epoch 1/4, Batch Accuracy: 0.4231
# Epoch 1/4, Batch Accuracy: 0.4235
# Epoch 1/4, Batch Accuracy: 0.4235
# Epoch 1/4, Batch Accuracy: 0.4236
# Epoch 1/4, Batch Accuracy: 0.4236
# Epoch 1/4, Batch Accuracy: 0.4238
# Epoch 1/4, Batch Accuracy: 0.4237
# Epoch 1/4, Batch Accuracy: 0.4239
# Epoch 1/4, Batch Accuracy: 0.4247
# Epoch 1/4, Batch Accuracy: 0.4255
# Epoch 1/4, Batch Accuracy: 0.4260
# Epoch 1/4, Batch Accuracy: 0.4266
# Epoch 1/4, Batch Accuracy: 0.4271
# Epoch 1/4, Batch Accuracy: 0.4276
# Epoch 1/4, Batch Accuracy: 0.4279
# Epoch 1/4, Batch Accuracy: 0.4281
# Epoch 1/4, Batch Accuracy: 0.4282
# Epoch 1/4, Batch Accuracy: 0.4290
# Epoch 1/4, Batch Accuracy: 0.4292
# Epoch 1/4, Batch Accuracy: 0.4300
# Epoch 1/4, Batch Accuracy: 0.4303
# Epoch 1/4, Batch Accuracy: 0.4306
# Epoch 1/4, Batch Accuracy: 0.4309
# Epoch 1/4, Batch Accuracy: 0.4314
# Epoch 1/4, Batch Accuracy: 0.4318
# Epoch 1/4, Batch Accuracy: 0.4320
# Epoch 1/4, Batch Accuracy: 0.4322
# Epoch 1/4, Batch Accuracy: 0.4323
# Epoch 1/4, Batch Accuracy: 0.4326
# Epoch 1/4, Batch Accuracy: 0.4334
# Epoch 1/4, Batch Accuracy: 0.4337
# Epoch 1/4, Batch Accuracy: 0.4344
# Epoch 1/4, Batch Accuracy: 0.4344
# Epoch 1/4, Batch Accuracy: 0.4349
# Epoch 1/4, Batch Accuracy: 0.4350
# Epoch 1/4, Batch Accuracy: 0.4350
# Epoch 1/4, Batch Accuracy: 0.4355
# Epoch 1/4, Batch Accuracy: 0.4363
# Epoch 1/4, Batch Accuracy: 0.4365
# Epoch 1/4, Batch Accuracy: 0.4365
# Epoch 1/4, Batch Accuracy: 0.4364
# Epoch 1/4, Batch Accuracy: 0.4369
# Epoch 1/4, Batch Accuracy: 0.4371
# Epoch 1/4, Batch Accuracy: 0.4371
# Epoch 1/4, Batch Accuracy: 0.4375
# Epoch 1/4, Batch Accuracy: 0.4375
# Epoch 1/4, Batch Accuracy: 0.4378
# Epoch 1/4, Batch Accuracy: 0.4383
# Epoch 1/4, Batch Accuracy: 0.4386
# Epoch 1/4, Batch Accuracy: 0.4392
# Epoch 1/4, Batch Accuracy: 0.4396
# Epoch 1/4, Batch Accuracy: 0.4399
# Epoch 1/4, Batch Accuracy: 0.4402
# Epoch 1/4, Batch Accuracy: 0.4404
# Epoch 1/4, Batch Accuracy: 0.4414
# Epoch 1/4, Batch Accuracy: 0.4421
# Epoch 1/4, Batch Accuracy: 0.4421
# Epoch 1/4, Batch Accuracy: 0.4421
# Epoch 1/4, Batch Accuracy: 0.4423
# Epoch 1/4, Batch Accuracy: 0.4427
# Epoch 1/4, Batch Accuracy: 0.4430
# Epoch 1/4, Batch Accuracy: 0.4432
# Epoch 1/4, Batch Accuracy: 0.4438
# Epoch 1/4, Batch Accuracy: 0.4440
# Epoch 1/4, Batch Accuracy: 0.4440
# Epoch 1/4, Batch Accuracy: 0.4441
# Epoch 1/4, Batch Accuracy: 0.4443
# Epoch 1/4, Batch Accuracy: 0.4444
# Epoch 1/4, Batch Accuracy: 0.4445
# Epoch 1/4, Batch Accuracy: 0.4446
# Epoch 1/4, Batch Accuracy: 0.4449
# Epoch 1/4, Batch Accuracy: 0.4451
# Epoch 1/4, Batch Accuracy: 0.4455
# Epoch 1/4, Batch Accuracy: 0.4463
# Epoch 1/4, Batch Accuracy: 0.4467
# Epoch 1/4, Batch Accuracy: 0.4472
# Epoch 1/4, Batch Accuracy: 0.4472
# Epoch 1/4, Batch Accuracy: 0.4473
# Epoch 1/4, Batch Accuracy: 0.4477
# Epoch 1/4, Batch Accuracy: 0.4476
# Epoch 1/4, Batch Accuracy: 0.4481
# Epoch 1/4, Batch Accuracy: 0.4482
# Epoch 1/4, Batch Accuracy: 0.4482
# Epoch 1/4, Batch Accuracy: 0.4485
# Epoch 1/4, Batch Accuracy: 0.4490
# Epoch 1/4, Batch Accuracy: 0.4493
# Epoch 1/4, Batch Accuracy: 0.4496
# Epoch 1/4, Batch Accuracy: 0.4498
# Epoch 1/4, Batch Accuracy: 0.4495
# Epoch 1/4, Batch Accuracy: 0.4496
# Epoch 1/4, Batch Accuracy: 0.4500
# Epoch 1/4, Batch Accuracy: 0.4502
# Epoch 1/4, Batch Accuracy: 0.4503
# Epoch 1/4, Batch Accuracy: 0.4502
# Epoch 1/4, Batch Accuracy: 0.4505
# Epoch 1/4, Batch Accuracy: 0.4506
# Epoch 1/4, Batch Accuracy: 0.4512
# Epoch 1/4, Batch Accuracy: 0.4514
# Epoch 1/4, Batch Accuracy: 0.4517
# Epoch 1/4, Batch Accuracy: 0.4518
# Epoch 1/4, Batch Accuracy: 0.4524
# Epoch 1/4, Batch Accuracy: 0.4528
# Epoch 1/4, Batch Accuracy: 0.4533
# Epoch 1/4, Batch Accuracy: 0.4538
# Epoch 1/4, Batch Accuracy: 0.4540
# Epoch 1/4, Batch Accuracy: 0.4541
# Epoch 1/4, Batch Accuracy: 0.4546
# Epoch 1/4, Batch Accuracy: 0.4548
# Epoch 1/4, Batch Accuracy: 0.4552
# Epoch 1/4, Batch Accuracy: 0.4554
# Epoch 1/4, Batch Accuracy: 0.4555
# Epoch 1/4, Batch Accuracy: 0.4556
# Epoch 1/4, Batch Accuracy: 0.4556
# Epoch 1/4, Batch Accuracy: 0.4557
# Epoch 1/4, Batch Accuracy: 0.4559
# Epoch 1/4, Batch Accuracy: 0.4560
# Epoch 1/4, Batch Accuracy: 0.4564
# Epoch 1/4, Batch Accuracy: 0.4569
# Epoch 1/4, Batch Accuracy: 0.4570
# Epoch 1/4, Batch Accuracy: 0.4573
# Epoch 1/4, Batch Accuracy: 0.4574
# Epoch 1/4, Batch Accuracy: 0.4579
# Epoch 1/4, Batch Accuracy: 0.4580
# Epoch 1/4, Batch Accuracy: 0.4585
# Epoch 1/4, Batch Accuracy: 0.4582
# Epoch 1/4, Batch Accuracy: 0.4590
# Epoch 1/4, Batch Accuracy: 0.4595
# Epoch 1/4, Batch Accuracy: 0.4597
# Epoch 1/4, Batch Accuracy: 0.4600
# Epoch 1/4, Batch Accuracy: 0.4606
# Epoch 1/4, Batch Accuracy: 0.4608
# Epoch 1/4, Batch Accuracy: 0.4611
# Epoch 1/4, Batch Accuracy: 0.4615
# Epoch 1/4, Batch Accuracy: 0.4614
# Epoch 1/4, Batch Accuracy: 0.4614
# Epoch 1/4, Batch Accuracy: 0.4620
# Epoch 1/4, Batch Accuracy: 0.4623
# Epoch 1/4, Batch Accuracy: 0.4626
# Epoch 1/4, Batch Accuracy: 0.4628
# Epoch 1/4, Batch Accuracy: 0.4626
# Epoch 1/4, Batch Accuracy: 0.4628
# Epoch 1/4, Batch Accuracy: 0.4631
# Epoch 1/4, Batch Accuracy: 0.4633
# Epoch 1/4, Batch Accuracy: 0.4630
# Epoch 1/4, Batch Accuracy: 0.4634
# Epoch 1/4, Batch Accuracy: 0.4637
# Epoch 1/4, Batch Accuracy: 0.4639
# Epoch 1/4, Batch Accuracy: 0.4639
# Epoch 1/4, Batch Accuracy: 0.4646
# Epoch 1/4, Batch Accuracy: 0.4649
# Epoch 1/4, Batch Accuracy: 0.4647
# Epoch 1/4, Batch Accuracy: 0.4649
# Epoch 1/4, Batch Accuracy: 0.4646
# Epoch 1/4, Batch Accuracy: 0.4651
# Epoch 1/4, Batch Accuracy: 0.4652
# Epoch 1/4, Batch Accuracy: 0.4653
# Epoch 1/4, Batch Accuracy: 0.4652
# Epoch 1/4, Batch Accuracy: 0.4653
# Epoch 1/4, Batch Accuracy: 0.4654
# Epoch 1/4, Batch Accuracy: 0.4658
# Epoch 1/4, Batch Accuracy: 0.4662
# Epoch 1/4, Batch Accuracy: 0.4661
# Epoch 1/4, Batch Accuracy: 0.4665
# Epoch 1/4, Batch Accuracy: 0.4670
# Epoch 1/4, Batch Accuracy: 0.4673
# Epoch 1/4, Batch Accuracy: 0.4674
# Epoch 1/4, Batch Accuracy: 0.4676
# Epoch 1/4, Batch Accuracy: 0.4681
# Epoch 1/4, Batch Accuracy: 0.4681
# Epoch 1/4, Batch Accuracy: 0.4687
# Epoch 1/4, Batch Accuracy: 0.4693
# Epoch 1/4, Batch Accuracy: 0.4696
# Epoch 1/4, Batch Accuracy: 0.4693
# Epoch 1/4, Batch Accuracy: 0.4698
# Epoch 1/4, Batch Accuracy: 0.4701
# Epoch 1/4, Batch Accuracy: 0.4697
# Epoch 1/4, Batch Accuracy: 0.4700
# Epoch 1/4, Batch Accuracy: 0.4704
# Epoch 1/4, Batch Accuracy: 0.4704
# Epoch 1/4, Batch Accuracy: 0.4705
# Epoch 1/4, Batch Accuracy: 0.4707
# Epoch 1/4, Batch Accuracy: 0.4712
# Epoch 1/4, Batch Accuracy: 0.4711
# Epoch 1/4, Batch Accuracy: 0.4711
# Epoch 1/4, Batch Accuracy: 0.4712
# Epoch 1/4, Batch Accuracy: 0.4718
# Epoch 1/4, Batch Accuracy: 0.4721
# Epoch 1/4, Batch Accuracy: 0.4717
# Epoch 1/4, Batch Accuracy: 0.4721
# Epoch 1/4, Batch Accuracy: 0.4724
# Epoch 1/4, Batch Accuracy: 0.4727
# Epoch 1/4, Batch Accuracy: 0.4728
# Epoch 1/4, Batch Accuracy: 0.4731
# Epoch 1/4, Batch Accuracy: 0.4734
# Epoch 1/4, Batch Accuracy: 0.4735
# Epoch 1/4, Batch Accuracy: 0.4735
# Epoch 1/4, Batch Accuracy: 0.4735
# Epoch 1/4, Batch Accuracy: 0.4740
# Epoch 1/4, Batch Accuracy: 0.4739
# Epoch 1/4, Batch Accuracy: 0.4745
# Epoch 1/4, Batch Accuracy: 0.4747
# Epoch 1/4, Batch Accuracy: 0.4748
# Epoch 1/4, Batch Accuracy: 0.4748
# Epoch 1/4, Batch Accuracy: 0.4747
# Epoch 1/4, Batch Accuracy: 0.4752
# Epoch 1/4, Batch Accuracy: 0.4756
# Epoch 1/4, Batch Accuracy: 0.4757
# Epoch 1/4, Batch Accuracy: 0.4757
# Epoch 1/4, Batch Accuracy: 0.4763
# Epoch 1/4, Batch Accuracy: 0.4763
# Epoch 1/4, Batch Accuracy: 0.4765
# Epoch 1/4, Batch Accuracy: 0.4766
# Epoch 1/4, Batch Accuracy: 0.4770
# Epoch 1/4, Batch Accuracy: 0.4774
# Epoch 1/4, Batch Accuracy: 0.4779
# Epoch 1/4, Batch Accuracy: 0.4780
# Epoch 1/4, Batch Accuracy: 0.4785
# Epoch 1/4, Batch Accuracy: 0.4786
# Epoch 1/4, Batch Accuracy: 0.4786
# Epoch 1/4, Batch Accuracy: 0.4789
# Epoch 1/4, Batch Accuracy: 0.4790
# Epoch 1/4, Batch Accuracy: 0.4792
# Epoch 1/4, Batch Accuracy: 0.4796
# Epoch 1/4, Batch Accuracy: 0.4799
# Epoch 1/4, Batch Accuracy: 0.4799
# Epoch 1/4, Batch Accuracy: 0.4805
# Epoch 1/4, Batch Accuracy: 0.4805
# Epoch 1/4, Batch Accuracy: 0.4807
# Epoch 1/4, Batch Accuracy: 0.4811
# Epoch 1/4, Batch Accuracy: 0.4813
# Epoch 1/4, Batch Accuracy: 0.4815
# Epoch 1/4, Batch Accuracy: 0.4820
# Epoch 1/4, Batch Accuracy: 0.4820
# Epoch 1/4, Batch Accuracy: 0.4822
# Epoch 1/4, Batch Accuracy: 0.4824
# Epoch 1/4, Batch Accuracy: 0.4825
# Epoch 1/4, Batch Accuracy: 0.4824
# Epoch 1/4, Batch Accuracy: 0.4829
# Epoch 1/4, Batch Accuracy: 0.4830
# Epoch 1/4, Batch Accuracy: 0.4832
# Epoch 1/4, Batch Accuracy: 0.4836
# Epoch 1/4, Batch Accuracy: 0.4839
# Epoch 1/4, Batch Accuracy: 0.4841
# Epoch 1/4, Batch Accuracy: 0.4843
# Epoch 1/4, Batch Accuracy: 0.4846
# Epoch 1/4, Batch Accuracy: 0.4850
# Epoch 1/4, Batch Accuracy: 0.4853
# Epoch 1/4, Batch Accuracy: 0.4853
# Epoch 1/4, Batch Accuracy: 0.4852
# Epoch 1/4, Batch Accuracy: 0.4858
# Epoch 1/4, Batch Accuracy: 0.4856
# Epoch 1/4, Batch Accuracy: 0.4859
# Epoch 1/4, Batch Accuracy: 0.4857
# Epoch 1/4, Batch Accuracy: 0.4858
# Epoch 1/4, Batch Accuracy: 0.4860
# Epoch 1/4, Batch Accuracy: 0.4862
# Epoch 1/4, Batch Accuracy: 0.4864
# Epoch 1/4, Batch Accuracy: 0.4865
# Epoch 1/4, Batch Accuracy: 0.4871
# Epoch 1/4, Batch Accuracy: 0.4870
# Epoch 1/4, Batch Accuracy: 0.4871
# Epoch 1/4, Batch Accuracy: 0.4873
# Epoch 1/4, Batch Accuracy: 0.4872
# Epoch 1/4, Batch Accuracy: 0.4871
# Epoch 1/4, Batch Accuracy: 0.4872
# Epoch 1/4, Batch Accuracy: 0.4874
# Epoch 1/4, Batch Accuracy: 0.4878
# Epoch 1/4, Batch Accuracy: 0.4884
# Epoch 1/4, Batch Accuracy: 0.4885
# Epoch 1/4, Batch Accuracy: 0.4886
# Epoch 1/4, Batch Accuracy: 0.4886
# Epoch 1/4, Batch Accuracy: 0.4888
# Epoch 1/4, Batch Accuracy: 0.4886
# Epoch 1/4, Batch Accuracy: 0.4893
# Epoch 1/4, Batch Accuracy: 0.4896
# Epoch 1/4, Batch Accuracy: 0.4897
# Epoch 1/4, Batch Accuracy: 0.4898
# Epoch 1/4, Batch Accuracy: 0.4900
# Epoch 1/4, Batch Accuracy: 0.4903
# Epoch 1/4, Batch Accuracy: 0.4906
# Epoch 1/4, Batch Accuracy: 0.4907
# Epoch 1/4, Batch Accuracy: 0.4905
# Epoch 1/4, Batch Accuracy: 0.4908
# Epoch 1/4, Batch Accuracy: 0.4905
# Epoch 1/4, Batch Accuracy: 0.4908
# Epoch 1/4, Batch Accuracy: 0.4909
# Epoch 1/4, Batch Accuracy: 0.4909
# Epoch 1/4, Batch Accuracy: 0.4911
# Epoch 1/4, Batch Accuracy: 0.4913
# Epoch 1/4, Batch Accuracy: 0.4912
# Epoch 1/4, Batch Accuracy: 0.4914
# Epoch 1/4, Batch Accuracy: 0.4917
# Epoch 1/4, Batch Accuracy: 0.4919
# Epoch 1/4, Batch Accuracy: 0.4920
# Epoch 1/4, Batch Accuracy: 0.4921
# Epoch 1/4, Batch Accuracy: 0.4924
# Epoch 1/4, Batch Accuracy: 0.4926
# Epoch 1/4, Batch Accuracy: 0.4924
# Epoch 1/4, Batch Accuracy: 0.4923
# Epoch 1/4, Batch Accuracy: 0.4923
# Epoch 1/4, Batch Accuracy: 0.4925
# Epoch 1/4, Batch Accuracy: 0.4926
# Epoch 1/4, Batch Accuracy: 0.4928
# Epoch 1/4, Batch Accuracy: 0.4928
# Epoch 1/4, Batch Accuracy: 0.4930
# Epoch 1/4, Batch Accuracy: 0.4930
# Epoch 1/4, Batch Accuracy: 0.4928
# Epoch 1/4, Batch Accuracy: 0.4930
# Epoch 1/4, Batch Accuracy: 0.4932
# Epoch 1/4, Batch Accuracy: 0.4931
# Epoch 1/4, Batch Accuracy: 0.4932
# Epoch 1/4, Batch Accuracy: 0.4935
# Epoch 1/4, Batch Accuracy: 0.4937
# Epoch 1/4, Batch Accuracy: 0.4935
# Epoch 1/4, Batch Accuracy: 0.4937
# Epoch 1/4, Batch Accuracy: 0.4938
# Epoch 1/4, Batch Accuracy: 0.4939
# Epoch 1/4, Batch Accuracy: 0.4939
# Epoch 1/4, Batch Accuracy: 0.4941
# Epoch 1/4, Batch Accuracy: 0.4943
# Epoch 1/4, Batch Accuracy: 0.4944
# Epoch 1/4, Batch Accuracy: 0.4945
# Epoch 1/4, Batch Accuracy: 0.4944
# Epoch 1/4, Batch Accuracy: 0.4945
# Epoch 1/4, Batch Accuracy: 0.4948
# Epoch 1/4, Batch Accuracy: 0.4952
# Epoch 1/4, Batch Accuracy: 0.4954
# Epoch 1/4, Batch Accuracy: 0.4956
# Epoch 1/4, Batch Accuracy: 0.4957
# Epoch 1/4, Batch Accuracy: 0.4960
# Epoch 1/4, Batch Accuracy: 0.4960
# Epoch 1/4, Batch Accuracy: 0.4960
# Epoch 1/4, Batch Accuracy: 0.4964
# Epoch 1/4, Batch Accuracy: 0.4965
# Epoch 1/4, Batch Accuracy: 0.4967
# Epoch 1/4, Batch Accuracy: 0.4967
# Epoch 1/4, Batch Accuracy: 0.4967
# Epoch 1/4, Batch Accuracy: 0.4969
# Epoch 1/4, Batch Accuracy: 0.4968
# Epoch 1/4, Batch Accuracy: 0.4969
# Epoch 1/4, Batch Accuracy: 0.4969
# Epoch 1/4, Batch Accuracy: 0.4970
# Epoch 1/4, Batch Accuracy: 0.4971
# Epoch 1/4, Batch Accuracy: 0.4974
# Epoch 1/4, Batch Accuracy: 0.4976
# Epoch 1/4, Batch Accuracy: 0.4978
# Epoch 1/4, Batch Accuracy: 0.4981
# Epoch 1/4, Batch Accuracy: 0.4983
# Epoch 1/4, Batch Accuracy: 0.4984
# Epoch 1/4, Batch Accuracy: 0.4986
# Epoch 1/4, Batch Accuracy: 0.4986
# Epoch 1/4, Batch Accuracy: 0.4987
# Epoch 1/4, Batch Accuracy: 0.4988
# Epoch 1/4, Batch Accuracy: 0.4988
# Epoch 1/4, Batch Accuracy: 0.4988
# Epoch 1/4, Batch Accuracy: 0.4992
# Epoch 1/4, Batch Accuracy: 0.4993
# Epoch 1/4, Batch Accuracy: 0.4995
# Epoch 1/4, Batch Accuracy: 0.4998
# Epoch 1/4, Batch Accuracy: 0.5000
# Epoch 1/4, Batch Accuracy: 0.5001
# Epoch 1/4, Batch Accuracy: 0.5003
# Epoch 1/4, Batch Accuracy: 0.5002
# Epoch 1/4, Batch Accuracy: 0.5002
# Epoch 1/4, Batch Accuracy: 0.5004
# Epoch 1/4, Batch Accuracy: 0.5006
# Epoch 1/4, Batch Accuracy: 0.5009
# Epoch 1/4, Batch Accuracy: 0.5011
# Epoch 1/4, Batch Accuracy: 0.5012
# Epoch 1/4, Batch Accuracy: 0.5016
# Epoch 1/4, Batch Accuracy: 0.5019
# Epoch 1/4, Batch Accuracy: 0.5018
# Epoch 1/4, Batch Accuracy: 0.5021
# Epoch 1/4, Batch Accuracy: 0.5025
# Epoch 1/4, Batch Accuracy: 0.5025
# Epoch 1/4, Batch Accuracy: 0.5026
# Epoch 1/4, Batch Accuracy: 0.5028
# Epoch 1/4, Batch Accuracy: 0.5031
# Epoch 1/4, Batch Accuracy: 0.5032
# Epoch 1/4, Batch Accuracy: 0.5035
# Epoch 1/4, Batch Accuracy: 0.5041
# Epoch 1/4, Batch Accuracy: 0.5043
# Epoch 1/4, Batch Accuracy: 0.5043
# Epoch 1/4, Batch Accuracy: 0.5045
# Epoch 1/4, Batch Accuracy: 0.5048
# Epoch 1/4, Batch Accuracy: 0.5052
# Epoch 1/4, Batch Accuracy: 0.5054
# Epoch 1/4, Batch Accuracy: 0.5057
# Epoch 1/4, Batch Accuracy: 0.5060
# Epoch 1/4, Batch Accuracy: 0.5062
# Epoch 1/4, Batch Accuracy: 0.5060
# Epoch 1/4, Batch Accuracy: 0.5059
# Epoch 1/4, Batch Accuracy: 0.5060
# Epoch 1/4, Batch Accuracy: 0.5060
# Epoch 1/4, Batch Accuracy: 0.5062
# Epoch 1/4, Batch Accuracy: 0.5062
# Epoch 1/4, Batch Accuracy: 0.5064
# Epoch 1/4, Batch Accuracy: 0.5066
# Epoch 1/4, Batch Accuracy: 0.5068
# Epoch 1/4, Batch Accuracy: 0.5068
# Epoch 1/4, Batch Accuracy: 0.5069
# Epoch 1/4, Batch Accuracy: 0.5068
# Epoch 1/4, Batch Accuracy: 0.5068
# Epoch 1/4, Batch Accuracy: 0.5073
# Epoch 1/4, Batch Accuracy: 0.5075
# Epoch 1/4, Batch Accuracy: 0.5074
# Epoch 1/4, Batch Accuracy: 0.5077
# Epoch 1/4, Batch Accuracy: 0.5076
# Epoch 1/4, Batch Accuracy: 0.5078
# Epoch 1/4, Batch Accuracy: 0.5080
# Epoch 1/4, Batch Accuracy: 0.5081
# Epoch 1/4, Batch Accuracy: 0.5082
# Epoch 1/4, Batch Accuracy: 0.5084
# Epoch 1/4, Batch Accuracy: 0.5085
# Epoch 1/4, Batch Accuracy: 0.5088
# Epoch 1/4, Batch Accuracy: 0.5089
# Epoch 1/4, Batch Accuracy: 0.5090
# Epoch 1/4, Batch Accuracy: 0.5092
# Epoch 1/4, Batch Accuracy: 0.5095
# Epoch 1/4, Batch Accuracy: 0.5096
# Epoch 1/4, Batch Accuracy: 0.5095
# Epoch 1/4, Batch Accuracy: 0.5093
# Epoch 1/4, Batch Accuracy: 0.5096
# Epoch 1/4, Batch Accuracy: 0.5097
# Epoch 1/4, Batch Accuracy: 0.5097
# Epoch 1/4, Batch Accuracy: 0.5101
# Epoch 1/4, Batch Accuracy: 0.5101
# Epoch 1/4, Batch Accuracy: 0.5103
# Epoch 1/4, Batch Accuracy: 0.5105
# Epoch 1/4, Batch Accuracy: 0.5108
# Epoch 1/4, Batch Accuracy: 0.5109
# Epoch 1/4, Batch Accuracy: 0.5112
# Epoch 1/4, Batch Accuracy: 0.5110
# Epoch 1/4, Batch Accuracy: 0.5112
# Epoch 1/4, Batch Accuracy: 0.5113
# Epoch 1/4, Batch Accuracy: 0.5114
# Epoch 1/4, Batch Accuracy: 0.5116
# Epoch 1/4, Batch Accuracy: 0.5117
# Epoch 1/4, Batch Accuracy: 0.5119
# Epoch 1/4, Batch Accuracy: 0.5122
# Epoch 1/4, Batch Accuracy: 0.5122
# Epoch 1/4, Batch Accuracy: 0.5125
# Epoch 1/4, Batch Accuracy: 0.5128
# Epoch 1/4, Batch Accuracy: 0.5127
# Epoch 1/4, Batch Accuracy: 0.5128
# Epoch 1/4, Batch Accuracy: 0.5130
# Epoch 1/4, Batch Accuracy: 0.5131
# Epoch 1/4, Batch Accuracy: 0.5132
# Epoch 1/4, Batch Accuracy: 0.5133
# Epoch 1/4, Batch Accuracy: 0.5135
# Epoch 1/4, Batch Accuracy: 0.5136
# Epoch 1/4, Batch Accuracy: 0.5137
# Epoch 1/4, Batch Accuracy: 0.5138
# Epoch 1/4, Batch Accuracy: 0.5138
# Epoch 1/4, Batch Accuracy: 0.5139
# Epoch 1/4, Batch Accuracy: 0.5142
# Epoch 1/4, Batch Accuracy: 0.5143
# Epoch 1/4, Batch Accuracy: 0.5145
# Epoch 1/4, Batch Accuracy: 0.5146
# Epoch 1/4, Batch Accuracy: 0.5146
# Epoch 1/4, Batch Accuracy: 0.5148
# Epoch 1/4, Batch Accuracy: 0.5150
# Epoch 1/4, Batch Accuracy: 0.5152
# Epoch 1/4, Batch Accuracy: 0.5149
# Epoch 1/4, Batch Accuracy: 0.5150
# Epoch 1/4, Batch Accuracy: 0.5152
# Epoch 1/4, Batch Accuracy: 0.5152
# Epoch 1/4, Batch Accuracy: 0.5152
# Epoch 1/4, Batch Accuracy: 0.5155
# Epoch 1/4, Batch Accuracy: 0.5155
# Epoch 1/4, Batch Accuracy: 0.5157
# Epoch 1/4, Batch Accuracy: 0.5156
# Epoch 1/4, Batch Accuracy: 0.5156
# Epoch 1/4, Batch Accuracy: 0.5157
# Epoch 1/4, Batch Accuracy: 0.5159
# Epoch 1/4, Batch Accuracy: 0.5160
# Epoch 1/4, Batch Accuracy: 0.5162
# Epoch 1/4, Batch Accuracy: 0.5164
# Epoch 1/4, Batch Accuracy: 0.5164
# Epoch 1/4, Batch Accuracy: 0.5166
# Epoch 1/4, Batch Accuracy: 0.5167
# Epoch 1/4, Batch Accuracy: 0.5167
# Epoch 1/4, Batch Accuracy: 0.5169
# Epoch 1/4, Batch Accuracy: 0.5171
# Epoch 1/4, Batch Accuracy: 0.5173
# Epoch 1/4, Batch Accuracy: 0.5174
# Epoch 1/4, Batch Accuracy: 0.5175
# Epoch 1/4, Batch Accuracy: 0.5176
# Epoch 1/4, Batch Accuracy: 0.5181
# Epoch 1/4, Batch Accuracy: 0.5184
# Epoch 1/4, Batch Accuracy: 0.5183
# Epoch 1/4, Batch Accuracy: 0.5186
# Epoch 1/4, Batch Accuracy: 0.5186
# Epoch 1/4, Batch Accuracy: 0.5186
# Epoch 1/4, Batch Accuracy: 0.5186
# Epoch 1/4, Batch Accuracy: 0.5189
# Epoch 1/4, Batch Accuracy: 0.5188
# Epoch 1/4, Batch Accuracy: 0.5188
# Epoch 1/4, Batch Accuracy: 0.5190
# Epoch 1/4, Batch Accuracy: 0.5190
# Epoch 1/4, Batch Accuracy: 0.5190
# Epoch 1/4, Batch Accuracy: 0.5192
# Epoch 1/4, Batch Accuracy: 0.5195
# Epoch 1/4, Batch Accuracy: 0.5196
# Epoch 1/4, Batch Accuracy: 0.5199
# Epoch 1/4, Batch Accuracy: 0.5199
# Epoch 1/4, Batch Accuracy: 0.5202
# Epoch 1/4, Batch Accuracy: 0.5203
# Epoch 1/4, Batch Accuracy: 0.5205
# Epoch 1/4, Batch Accuracy: 0.5206
# Epoch 1/4, Batch Accuracy: 0.5206
# Epoch 1/4, Batch Accuracy: 0.5207
# Epoch 1/4, Batch Accuracy: 0.5207
# Epoch 1/4, Batch Accuracy: 0.5209
# Epoch 1/4, Batch Accuracy: 0.5210
# Epoch 1/4, Batch Accuracy: 0.5211
# Epoch 1/4, Batch Accuracy: 0.5212
# Epoch 1/4, Batch Accuracy: 0.5212
# Epoch 1/4, Batch Accuracy: 0.5211
# Epoch 1/4, Batch Accuracy: 0.5210
# Epoch 1/4, Batch Accuracy: 0.5212
# Epoch 1/4, Batch Accuracy: 0.5213
# Epoch 1/4, Batch Accuracy: 0.5213
# Epoch 1/4, Batch Accuracy: 0.5214
# Epoch 1/4, Batch Accuracy: 0.5216
# Epoch 1/4, Batch Accuracy: 0.5218
# Epoch 1/4, Batch Accuracy: 0.5220
# Epoch 1/4, Batch Accuracy: 0.5223
# Epoch 1/4, Batch Accuracy: 0.5225
# Epoch 1/4, Batch Accuracy: 0.5226
# Epoch 1/4, Batch Accuracy: 0.5227
# Epoch 1/4, Batch Accuracy: 0.5228
# Epoch 1/4, Batch Accuracy: 0.5230
# Epoch 1/4, Batch Accuracy: 0.5229
# Epoch 1/4, Batch Accuracy: 0.5231
# Epoch 1/4, Batch Accuracy: 0.5232
# Epoch 1/4, Batch Accuracy: 0.5232
# Epoch 1/4, Batch Accuracy: 0.5232
# Epoch 1/4, Batch Accuracy: 0.5234
# Epoch 1/4, Batch Accuracy: 0.5235
# Epoch 1/4, Batch Accuracy: 0.5239
# Epoch 1/4, Batch Accuracy: 0.5240
# Epoch 1/4, Batch Accuracy: 0.5241
# Epoch 1/4, Batch Accuracy: 0.5242
# Epoch 1/4, Batch Accuracy: 0.5246
# Epoch 1/4, Batch Accuracy: 0.5248
# Epoch 1/4, Batch Accuracy: 0.5249
# Epoch 1/4, Batch Accuracy: 0.5252
# Epoch 1/4, Batch Accuracy: 0.5252
# Epoch 1/4, Batch Accuracy: 0.5251
# Epoch 1/4, Batch Accuracy: 0.5253
# Epoch 1/4, Batch Accuracy: 0.5254
# Epoch 1/4, Batch Accuracy: 0.5254
# Epoch 1/4, Batch Accuracy: 0.5256
# Epoch 1/4, Batch Accuracy: 0.5255
# Epoch 1/4, Batch Accuracy: 0.5257
# Epoch 1/4, Batch Accuracy: 0.5258
# Epoch 1/4, Batch Accuracy: 0.5258
# Epoch 1/4, Batch Accuracy: 0.5261
# Epoch 1/4, Batch Accuracy: 0.5262
# Epoch 1/4, Batch Accuracy: 0.5263
# Epoch 1/4, Batch Accuracy: 0.5264
# Epoch 1/4, Batch Accuracy: 0.5266
# Epoch 1/4, Batch Accuracy: 0.5265
# Epoch 1/4, Batch Accuracy: 0.5266
# Epoch 1/4, Batch Accuracy: 0.5267
# Epoch 1/4, Batch Accuracy: 0.5270
# Epoch 1/4, Batch Accuracy: 0.5270
# Epoch 1/4, Batch Accuracy: 0.5273
# Epoch 1/4, Batch Accuracy: 0.5273
# Epoch 1/4, Batch Accuracy: 0.5274
# Epoch 1/4, Batch Accuracy: 0.5275
# Epoch 1/4, Batch Accuracy: 0.5278
# Epoch 1/4, Batch Accuracy: 0.5276
# Epoch 1/4, Batch Accuracy: 0.5276
# Epoch 1/4, Batch Accuracy: 0.5276
# Epoch 1/4, Batch Accuracy: 0.5278
# Epoch 1/4, Batch Accuracy: 0.5280
# Epoch 1/4, Batch Accuracy: 0.5283
# Epoch 1/4, Batch Accuracy: 0.5284
# Epoch 1/4, Batch Accuracy: 0.5286
# Epoch 1/4, Batch Accuracy: 0.5289
# Epoch 1/4, Batch Accuracy: 0.5289
# Epoch 1/4, Batch Accuracy: 0.5292
# Epoch 1/4, Batch Accuracy: 0.5294
# Epoch 1/4, Batch Accuracy: 0.5296
# Epoch 1/4, Batch Accuracy: 0.5297
# Epoch 1/4, Batch Accuracy: 0.5299
# Epoch 1/4, Batch Accuracy: 0.5302
# Epoch 1/4, Batch Accuracy: 0.5304
# Epoch 1/4, Batch Accuracy: 0.5304
# Epoch 1/4, Batch Accuracy: 0.5303
# Epoch 1/4, Batch Accuracy: 0.5306
# Epoch 1/4, Batch Accuracy: 0.5306
# Epoch 1/4, Batch Accuracy: 0.5307
# Epoch 1/4, Batch Accuracy: 0.5309
# Epoch 1/4, Batch Accuracy: 0.5309
# Epoch 1/4, Batch Accuracy: 0.5308
# Epoch 1/4, Batch Accuracy: 0.5309
# Epoch 1/4, Batch Accuracy: 0.5310
# Epoch 1/4, Batch Accuracy: 0.5312
# Epoch 1/4, Batch Accuracy: 0.5313
# Epoch 1/4, Batch Accuracy: 0.5318
# Epoch 1/4, Batch Accuracy: 0.5317
# Epoch 1/4, Batch Accuracy: 0.5318
# Epoch 1/4, Batch Accuracy: 0.5319
# Epoch 1/4, Batch Accuracy: 0.5318
# Epoch 1/4, Batch Accuracy: 0.5318
# Epoch 1/4, Batch Accuracy: 0.5317
# Epoch 1/4, Batch Accuracy: 0.5320
# Epoch 1/4, Batch Accuracy: 0.5322
# Epoch 1/4, Batch Accuracy: 0.5323
# Epoch 1/4, Batch Accuracy: 0.5322
# Epoch 1/4, Batch Accuracy: 0.5323
# Epoch 1/4, Batch Accuracy: 0.5322
# Epoch 1/4, Batch Accuracy: 0.5324
# Epoch 1/4, Batch Accuracy: 0.5325
# Epoch 1/4, Batch Accuracy: 0.5325
# Epoch 1/4, Batch Accuracy: 0.5326
# Epoch 1/4, Batch Accuracy: 0.5328
# Epoch 1/4, Batch Accuracy: 0.5328
# Epoch 1/4, Batch Accuracy: 0.5331
# Epoch 1/4, Batch Accuracy: 0.5330
# Epoch 1/4, Batch Accuracy: 0.5329
# Epoch 1/4, Batch Accuracy: 0.5330
# Epoch 1/4, Batch Accuracy: 0.5331
# Epoch 1/4, Batch Accuracy: 0.5334
# Epoch 1/4, Batch Accuracy: 0.5334
# Epoch 1/4, Batch Accuracy: 0.5333
# Epoch 1/4, Batch Accuracy: 0.5334
# Epoch 1/4, Batch Accuracy: 0.5336
# Epoch 1/4, Batch Accuracy: 0.5337
# Epoch 1/4, Batch Accuracy: 0.5338
# Epoch 1/4, Batch Accuracy: 0.5338
# Epoch 1/4, Batch Accuracy: 0.5339
# Epoch 1/4, Batch Accuracy: 0.5339
# Epoch 1/4, Batch Accuracy: 0.5340
# Epoch 1/4, Batch Accuracy: 0.5340
# Epoch 1/4, Batch Accuracy: 0.5340
# Epoch 1/4, Batch Accuracy: 0.5343
# Epoch 1/4, Batch Accuracy: 0.5345
# Epoch 1/4, Batch Accuracy: 0.5345
# Epoch 1/4, Batch Accuracy: 0.5347
# Epoch 1/4, Batch Accuracy: 0.5348
# Epoch 1/4, Batch Accuracy: 0.5349
# Epoch 1/4, Batch Accuracy: 0.5351
# Epoch 1/4, Batch Accuracy: 0.5350
# Epoch 1/4, Batch Accuracy: 0.5352
# Epoch 1/4, Batch Accuracy: 0.5357
# Epoch 1/4, Batch Accuracy: 0.5358
# Epoch 1/4, Batch Accuracy: 0.5359
# Epoch 1/4, Batch Accuracy: 0.5359
# Epoch 1/4, Batch Accuracy: 0.5358
# Epoch 1/4, Batch Accuracy: 0.5360
# Epoch 1/4, Batch Accuracy: 0.5361
# Epoch 1/4, Batch Accuracy: 0.5360
# Epoch 1/4, Batch Accuracy: 0.5362
# Epoch 1/4, Batch Accuracy: 0.5362
# Epoch 1/4, Batch Accuracy: 0.5364
# Epoch 1/4, Batch Accuracy: 0.5366
# Epoch 1/4, Batch Accuracy: 0.5366
# Epoch 1/4, Batch Accuracy: 0.5366
# Epoch 1/4, Batch Accuracy: 0.5367
# Epoch 1/4, Batch Accuracy: 0.5369
# Epoch 1/4, Batch Accuracy: 0.5371
# Epoch 1/4, Batch Accuracy: 0.5375
# Epoch 1/4, Batch Accuracy: 0.5378
# Epoch 1/4, Batch Accuracy: 0.5379
# Epoch 1/4, Batch Accuracy: 0.5379
# Epoch 1/4, Batch Accuracy: 0.5381
# Epoch 1/4, Batch Accuracy: 0.5380
# Epoch 1/4, Batch Accuracy: 0.5381
# Epoch 1/4, Batch Accuracy: 0.5383
# Epoch 1/4, Batch Accuracy: 0.5384
# Epoch 1/4, Batch Accuracy: 0.5385
# Epoch 1/4, Batch Accuracy: 0.5384
# Epoch 1/4, Batch Accuracy: 0.5385
# Epoch 1/4, Batch Accuracy: 0.5387
# Epoch 1/4, Batch Accuracy: 0.5389
# Epoch 1/4, Batch Accuracy: 0.5392
# Epoch 1/4, Batch Accuracy: 0.5394
# Epoch 1/4, Batch Accuracy: 0.5396
# Epoch 1/4, Batch Accuracy: 0.5398
# Epoch 1/4, Batch Accuracy: 0.5400
# Epoch 1/4, Batch Accuracy: 0.5402
# Epoch 1/4, Batch Accuracy: 0.5404
# Epoch 1/4, Batch Accuracy: 0.5405
# Epoch 1/4, Batch Accuracy: 0.5407
# Epoch 1/4, Batch Accuracy: 0.5409
# Epoch 1/4, Batch Accuracy: 0.5410
# Epoch 1/4, Batch Accuracy: 0.5411
# Epoch 1/4, Batch Accuracy: 0.5415
# Epoch 1/4, Batch Accuracy: 0.5415
# Epoch 1/4, Batch Accuracy: 0.5417
# Epoch 1/4, Batch Accuracy: 0.5420
# Epoch 1/4, Batch Accuracy: 0.5422
# Epoch 1/4, Batch Accuracy: 0.5421
# Epoch 1/4, Batch Accuracy: 0.5421
# Epoch 1/4, Batch Accuracy: 0.5422
# Epoch 1/4, Batch Accuracy: 0.5422
# Epoch 1/4, Batch Accuracy: 0.5422
# Epoch 1/4, Batch Accuracy: 0.5423
# Epoch 1/4, Batch Accuracy: 0.5425
# Epoch 1/4, Batch Accuracy: 0.5424
# Epoch 1/4, Batch Accuracy: 0.5427
# Epoch 1/4, Batch Accuracy: 0.5427
# Epoch 1/4, Batch Accuracy: 0.5428
# Epoch 1/4, Batch Accuracy: 0.5430
# Epoch 1/4, Batch Accuracy: 0.5430
# Epoch 1/4, Batch Accuracy: 0.5433
# Epoch 1/4, Batch Accuracy: 0.5433
# Epoch 1/4, Batch Accuracy: 0.5435
# Epoch 1/4, Batch Accuracy: 0.5434
# Epoch 1/4, Batch Accuracy: 0.5436
# Epoch 1/4, Batch Accuracy: 0.5437
# Epoch 1/4, Batch Accuracy: 0.5437
# Epoch 1/4, Batch Accuracy: 0.5436
# Epoch 1/4, Batch Accuracy: 0.5437
# Epoch 1/4, Batch Accuracy: 0.5439
# Epoch 1/4, Batch Accuracy: 0.5440
# Epoch 1/4, Batch Accuracy: 0.5441
# Epoch 1/4, Batch Accuracy: 0.5443
# Epoch 1/4, Batch Accuracy: 0.5443
# Epoch 1/4, Batch Accuracy: 0.5443
# Epoch 1/4, Batch Accuracy: 0.5445
# Epoch 1/4, Batch Accuracy: 0.5444
# Epoch 1/4, Batch Accuracy: 0.5446
# Epoch 1/4, Batch Accuracy: 0.5445
# Epoch 1/4, Batch Accuracy: 0.5446
# Epoch 1/4, Batch Accuracy: 0.5445
# Epoch 1/4, Batch Accuracy: 0.5446
# Epoch 1/4, Batch Accuracy: 0.5448
# Epoch 1/4, Batch Accuracy: 0.5449
# Epoch 1/4, Batch Accuracy: 0.5452
# Epoch 1/4, Batch Accuracy: 0.5451
# Epoch 1/4, Batch Accuracy: 0.5453
# Epoch 1/4, Batch Accuracy: 0.5454
# Epoch 1/4, Batch Accuracy: 0.5456
# Epoch 1/4, Batch Accuracy: 0.5456
# Epoch 1/4, Batch Accuracy: 0.5456
# Epoch 1/4, Batch Accuracy: 0.5454
# Epoch 1/4, Batch Accuracy: 0.5452
# Epoch 1/4, Batch Accuracy: 0.5453
# Epoch 1/4, Batch Accuracy: 0.5454
# Epoch 1/4, Batch Accuracy: 0.5457
# Epoch 1/4, Batch Accuracy: 0.5456
# Epoch 1/4, Batch Accuracy: 0.5457
# Epoch 1/4, Batch Accuracy: 0.5459
# Epoch 1/4, Batch Accuracy: 0.5459
# Epoch 1/4, Batch Accuracy: 0.5461
# Epoch 1/4, Batch Accuracy: 0.5461
# Epoch 1/4, Batch Accuracy: 0.5462
# Epoch 1/4, Batch Accuracy: 0.5463
# Epoch 1/4, Batch Accuracy: 0.5465
# Epoch 1/4, Batch Accuracy: 0.5466
# Epoch 1/4, Batch Accuracy: 0.5468
# Epoch 1/4, Batch Accuracy: 0.5470
# Epoch 1/4, Batch Accuracy: 0.5470
# Epoch 1/4, Batch Accuracy: 0.5470
# Epoch 1/4, Batch Accuracy: 0.5471
# Epoch 1/4, Batch Accuracy: 0.5473
# Epoch 1/4, Batch Accuracy: 0.5473
# Epoch 1/4, Batch Accuracy: 0.5475
# Epoch 1/4, Batch Accuracy: 0.5477
# Epoch 1/4, Batch Accuracy: 0.5477
# Epoch 1/4, Batch Accuracy: 0.5479
# Epoch 1/4, Batch Accuracy: 0.5480
# Epoch 1/4, Batch Accuracy: 0.5482
# Epoch 1/4, Batch Accuracy: 0.5481
# Epoch 1/4, Batch Accuracy: 0.5480
# Epoch 1/4, Batch Accuracy: 0.5480
# Epoch 1/4, Batch Accuracy: 0.5481
# Epoch 1/4, Batch Accuracy: 0.5483
# Epoch 1/4, Batch Accuracy: 0.5487
# Epoch 1/4, Batch Accuracy: 0.5487
# Epoch 1/4, Batch Accuracy: 0.5486
# Epoch 1/4, Batch Accuracy: 0.5488
# Epoch 1/4, Batch Accuracy: 0.5489
# Epoch 1/4, Batch Accuracy: 0.5491
# Epoch 1/4, Batch Accuracy: 0.5494
# Epoch 1/4, Batch Accuracy: 0.5495
# Epoch 1/4, Batch Accuracy: 0.5496
# Epoch 1/4, Batch Accuracy: 0.5499
# Epoch 1/4, Batch Accuracy: 0.5498
# Epoch 1/4, Batch Accuracy: 0.5499
# Epoch 1/4, Batch Accuracy: 0.5500
# Epoch 1/4, Batch Accuracy: 0.5501
# Epoch 1/4, Batch Accuracy: 0.5502
# Epoch 1/4, Batch Accuracy: 0.5503
# Epoch 1/4, Batch Accuracy: 0.5505
# Epoch 1/4, Batch Accuracy: 0.5506
# Epoch 1/4, Batch Accuracy: 0.5508
# Epoch 1/4, Batch Accuracy: 0.5508
# Epoch 1/4, Batch Accuracy: 0.5509
# Epoch 1/4, Batch Accuracy: 0.5511
# Epoch 1/4, Batch Accuracy: 0.5511
# Epoch 1/4, Batch Accuracy: 0.5512
# Epoch 1/4, Batch Accuracy: 0.5514
# Epoch 1/4, Batch Accuracy: 0.5515
# Epoch 1/4, Batch Accuracy: 0.5516
# Epoch 1/4, Batch Accuracy: 0.5518
# Epoch 1/4, Batch Accuracy: 0.5518
# Epoch 1/4, Batch Accuracy: 0.5519
# Epoch 1/4, Batch Accuracy: 0.5520
# Epoch 1/4, Batch Accuracy: 0.5519
# Epoch 1/4, Batch Accuracy: 0.5520
# Epoch 1/4, Batch Accuracy: 0.5519
# Epoch 1/4, Batch Accuracy: 0.5519
# Epoch 1/4, Batch Accuracy: 0.5522
# Epoch 1/4, Batch Accuracy: 0.5524
# Epoch 1/4, Batch Accuracy: 0.5524
# Epoch 1/4, Batch Accuracy: 0.5526
# Epoch 1/4, Batch Accuracy: 0.5527
# Epoch 1/4, Batch Accuracy: 0.5528
# Epoch 1/4, Batch Accuracy: 0.5530
# Epoch 1/4, Batch Accuracy: 0.5531
# Epoch 1/4, Batch Accuracy: 0.5532
# Epoch 1/4, Batch Accuracy: 0.5533
# Epoch 1/4, Batch Accuracy: 0.5536
# Epoch 1/4, Batch Accuracy: 0.5536
# Epoch 1/4, Batch Accuracy: 0.5537
# Epoch 1/4, Batch Accuracy: 0.5538
# Epoch 1/4, Batch Accuracy: 0.5540
# Epoch 1/4, Batch Accuracy: 0.5541
# Epoch 1/4, Batch Accuracy: 0.5543
# Epoch 1/4, Batch Accuracy: 0.5542
# Epoch 1/4, Batch Accuracy: 0.5544
# Epoch 1/4, Batch Accuracy: 0.5546
# Epoch 1/4, Batch Accuracy: 0.5547
# Epoch 1/4, Batch Accuracy: 0.5547
# Epoch 1/4, Batch Accuracy: 0.5548
# Epoch 1/4, Batch Accuracy: 0.5549
# Epoch 1/4, Batch Accuracy: 0.5550
# Epoch 1/4, Batch Accuracy: 0.5549
# Epoch 1/4, Batch Accuracy: 0.5550
# Epoch 1/4, Batch Accuracy: 0.5550
# Epoch 1/4, Batch Accuracy: 0.5550
# Epoch 1/4, Batch Accuracy: 0.5550
# Epoch 1/4, Batch Accuracy: 0.5551
# Epoch 1/4, Batch Accuracy: 0.5551
# Epoch 1/4, Batch Accuracy: 0.5553
# Epoch 1/4, Batch Accuracy: 0.5555
# Epoch 1/4, Batch Accuracy: 0.5556
# Epoch 1/4, Batch Accuracy: 0.5557
# Epoch 1/4, Batch Accuracy: 0.5557
# Epoch 1/4, Batch Accuracy: 0.5559
# Epoch 1/4, Batch Accuracy: 0.5558
# Epoch 1/4, Batch Accuracy: 0.5559
# Epoch 1/4, Batch Accuracy: 0.5562
# Epoch 1/4, Batch Accuracy: 0.5561
# Epoch 1/4, Batch Accuracy: 0.5563
# Epoch 1/4, Batch Accuracy: 0.5564
# Epoch 1/4, Batch Accuracy: 0.5566
# Epoch 1/4, Batch Accuracy: 0.5564
# Epoch 1/4, Batch Accuracy: 0.5565
# Epoch 1/4, Batch Accuracy: 0.5568
# Epoch 1/4, Batch Accuracy: 0.5571
# Epoch 1/4, Batch Accuracy: 0.5573
# Epoch 1/4, Batch Accuracy: 0.5575
# Epoch 1/4, Batch Accuracy: 0.5576
# Epoch 1/4, Batch Accuracy: 0.5577
# Epoch 1/4, Batch Accuracy: 0.5578
# Epoch 1/4, Batch Accuracy: 0.5578
# Epoch 1/4, Batch Accuracy: 0.5580
# Epoch 1/4, Batch Accuracy: 0.5579
# Epoch 1/4, Batch Accuracy: 0.5581
# Epoch 1/4, Batch Accuracy: 0.5582
# Epoch 1/4, Batch Accuracy: 0.5583
# Epoch 1/4, Batch Accuracy: 0.5585
# Epoch 1/4, Batch Accuracy: 0.5586
# Epoch 1/4, Batch Accuracy: 0.5587
# Epoch 1/4, Batch Accuracy: 0.5589
# Epoch 1/4, Batch Accuracy: 0.5589
# Epoch 1/4, Batch Accuracy: 0.5590
# Epoch 1/4, Batch Accuracy: 0.5592
# Epoch 1/4, Batch Accuracy: 0.5594
# Epoch 1/4, Batch Accuracy: 0.5596
# Epoch 1/4, Batch Accuracy: 0.5598
# Epoch 1/4, Batch Accuracy: 0.5599
# Epoch 1/4, Batch Accuracy: 0.5600
# Epoch 1/4, Batch Accuracy: 0.5601
# Epoch 1/4, Batch Accuracy: 0.5602
# Epoch 1/4, Batch Accuracy: 0.5603
# Epoch 1/4, Batch Accuracy: 0.5603
# Epoch 1/4, Batch Accuracy: 0.5605
# Epoch 1/4, Batch Accuracy: 0.5605
# Epoch 1/4, Batch Accuracy: 0.5606
# Epoch 1/4, Batch Accuracy: 0.5607
# Epoch 1/4, Batch Accuracy: 0.5607
# Epoch 1/4, Batch Accuracy: 0.5608
# Epoch 1/4, Batch Accuracy: 0.5608
# Epoch 1/4, Batch Accuracy: 0.5611
# Epoch 1/4, Batch Accuracy: 0.5613
# Epoch 1/4, Batch Accuracy: 0.5612
# Epoch 1/4, Batch Accuracy: 0.5614
# Epoch 1/4, Batch Accuracy: 0.5614
# Epoch 1/4, Batch Accuracy: 0.5615
# Epoch 1/4, Batch Accuracy: 0.5615
# Epoch 1/4, Batch Accuracy: 0.5617
# Epoch 1/4, Batch Accuracy: 0.5619
# Epoch 1/4, Batch Accuracy: 0.5621
# Epoch 1/4, Batch Accuracy: 0.5621
# Epoch 1/4, Batch Accuracy: 0.5623
# Epoch 1/4, Batch Accuracy: 0.5625
# Epoch 1/4, Batch Accuracy: 0.5627
# Epoch 1/4, Batch Accuracy: 0.5630
# Epoch 1/4, Batch Accuracy: 0.5631
# Epoch 1/4, Batch Accuracy: 0.5633
# Epoch 1/4, Batch Accuracy: 0.5633
# Epoch 1/4, Batch Accuracy: 0.5633
# Epoch 1/4, Batch Accuracy: 0.5635
# Epoch 1/4, Batch Accuracy: 0.5636
# Epoch 1/4, Batch Accuracy: 0.5636
# Epoch 1/4, Batch Accuracy: 0.5637
# Epoch 1/4, Batch Accuracy: 0.5637
# Epoch 1/4, Batch Accuracy: 0.5638
# Epoch 1/4, Batch Accuracy: 0.5638
# Epoch 1/4, Batch Accuracy: 0.5639
# Epoch 1/4, Batch Accuracy: 0.5640
# Epoch 1/4, Batch Accuracy: 0.5643
# Epoch 1/4, Batch Accuracy: 0.5645
# Epoch 1/4, Batch Accuracy: 0.5645
# Epoch 1/4, Batch Accuracy: 0.5645
# Epoch 1/4, Batch Accuracy: 0.5646
# Epoch 1/4, Batch Accuracy: 0.5647
# Epoch 1/4, Batch Accuracy: 0.5648
# Epoch 1/4, Batch Accuracy: 0.5648
# Epoch 1/4, Batch Accuracy: 0.5650
# Epoch 1/4, Batch Accuracy: 0.5651
# Epoch 1/4, Batch Accuracy: 0.5652
# Epoch 1/4, Batch Accuracy: 0.5654
# Epoch 1/4, Batch Accuracy: 0.5655
# Epoch 1/4, Batch Accuracy: 0.5655
# Epoch 1/4, Batch Accuracy: 0.5656
# Epoch 1/4, Batch Accuracy: 0.5656
# Epoch 1/4, Batch Accuracy: 0.5657
# Epoch 1/4, Batch Accuracy: 0.5658
# Epoch 1/4, Batch Accuracy: 0.5659
# Epoch 1/4, Batch Accuracy: 0.5659
# Epoch 1/4, Batch Accuracy: 0.5659
# Epoch 1/4, Batch Accuracy: 0.5661
# Epoch 1/4, Batch Accuracy: 0.5661
# Epoch 1/4, Batch Accuracy: 0.5663
# Epoch 1/4, Batch Accuracy: 0.5664
# Epoch 1/4, Batch Accuracy: 0.5664
# Epoch 1/4, Batch Accuracy: 0.5666
# Epoch 1/4, Batch Accuracy: 0.5666
# Epoch 1/4, Batch Accuracy: 0.5668
# Epoch 1/4, Batch Accuracy: 0.5670
# Epoch 1/4, Batch Accuracy: 0.5671
# Epoch 1/4, Batch Accuracy: 0.5672
# Epoch 1/4, Batch Accuracy: 0.5673
# Epoch 1/4, Batch Accuracy: 0.5675
# Epoch 1/4, Batch Accuracy: 0.5675
# Epoch 1/4, Batch Accuracy: 0.5676
# Epoch 1/4, Batch Accuracy: 0.5676
# Epoch 1/4, Batch Accuracy: 0.5678
# Epoch 1/4, Batch Accuracy: 0.5681
# Epoch 1/4, Batch Accuracy: 0.5681
# Epoch 1/4, Batch Accuracy: 0.5682
# Epoch 1/4, Batch Accuracy: 0.5682
# Epoch 1/4, Batch Accuracy: 0.5682
# Epoch 1/4, Batch Accuracy: 0.5681
# Epoch 1/4, Batch Accuracy: 0.5682
# Epoch 1/4, Batch Accuracy: 0.5681
# Epoch 1/4, Batch Accuracy: 0.5682
# Epoch 1/4, Batch Accuracy: 0.5683
# Epoch 1/4, Batch Accuracy: 0.5683
# Epoch 1/4, Batch Accuracy: 0.5684
# Epoch 1/4, Batch Accuracy: 0.5684
# Epoch 1/4, Batch Accuracy: 0.5684
# Epoch 1/4, Batch Accuracy: 0.5685
# Epoch 1/4, Batch Accuracy: 0.5686
# Epoch 1/4, Batch Accuracy: 0.5688
# Epoch 1/4, Batch Accuracy: 0.5689
# Epoch 1/4, Batch Accuracy: 0.5690
# Epoch 1/4, Batch Accuracy: 0.5692
# Epoch 1/4, Batch Accuracy: 0.5693
# Epoch 1/4, Batch Accuracy: 0.5693
# Epoch 1/4, Batch Accuracy: 0.5691
# Epoch 1/4, Batch Accuracy: 0.5693
# Epoch 1/4, Batch Accuracy: 0.5694
# Epoch 1/4, Batch Accuracy: 0.5694
# Epoch 1/4, Batch Accuracy: 0.5696
# Epoch 1/4, Batch Accuracy: 0.5697
# Epoch 1/4, Batch Accuracy: 0.5699
# Epoch 1/4, Batch Accuracy: 0.5700
# Epoch 1/4, Batch Accuracy: 0.5699
# Epoch 1/4, Batch Accuracy: 0.5700
# Epoch 1/4, Batch Accuracy: 0.5699
# Epoch 1/4, Batch Accuracy: 0.5700
# Epoch 1/4, Batch Accuracy: 0.5700
# Epoch 1/4, Batch Accuracy: 0.5702
# Epoch 1/4, Batch Accuracy: 0.5703
# Epoch 1/4, Batch Accuracy: 0.5703
# Epoch 1/4, Batch Accuracy: 0.5705
# Epoch 1/4, Batch Accuracy: 0.5707
# Epoch 1/4, Batch Accuracy: 0.5708
# Epoch 1/4, Batch Accuracy: 0.5707
# ...
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8231
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8227
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8228
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8229
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
# Epoch 4/4, Batch Accuracy: 0.8230
#   0%|          | 0/2166 [00:00<?, ?it/s]
# Epoch 4/4, Train Loss: 0.4979, Train Accuracy: 0.8230, Test Loss: 0.6037, Test Accuracy: 0.7906
#   0%|          | 0/2166 [00:00<?, ?it/s]
# F1 Score: 0.7882505968421499

# %%
model.eval()

test_correct = 0
test_total = 0

for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
  y_batch = y_batch.to(device)
  y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
  _, predicted = torch.max(y_pred, 1)
  test_correct += (predicted == y_batch).sum()
  test_total += len(y_batch)

print("Accuracy:", test_correct.float() / test_total)
# Out:
#   0%|          | 0/2166 [00:00<?, ?it/s]
# /home/kdt-admin/miniconda3/envs/kti/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2688: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Accuracy: tensor(0.7906, device='cuda:0')

# %%
# 모델 저장하기
torch.save(model.state_dict(), "modelfinal.pt")

# %%
# 토크나이저 설정
tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")

# %%
koelectra_tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")

result = koelectra_tokenizer.tokenize("너는 내년 대선 때 투표할 수 있어?")
print(result)
print([koelectra_tokenizer.encode(token) for token in result])
# Out:
# ['너', '##는', '내년', '대선', '때', '투표', '##할', '수', '있', '##어', '?']
# [[2, 2267, 3], [2, 7, 7, 2331, 3], [2, 6821, 3], [2, 7167, 3], [2, 2468, 3], [2, 7070, 3], [2, 7, 7, 3758, 3], [2, 2967, 3], [2, 3249, 3], [2, 7, 7, 3114, 3], [2, 35, 3]]

# %%
# 감정 예측 함수
def predict_emotion(input_sentence):
    inputs = tokenizer(input_sentence, return_tensors="pt", max_length=75, padding=True, truncation=True)
    input_ids = inputs["input_ids"].to(device)
    attention_mask = inputs["attention_mask"].to(device)

    with torch.no_grad():
        output = model(input_ids, attention_mask=attention_mask)
        logits = output.logits

    predicted_label = torch.argmax(logits, dim=1).item()
    emotions = ["중립", "슬픔", "분노", "불안", "행복", "당황"]
    predicted_emotion = emotions[predicted_label]

    return predicted_emotion

# %%
class_names = ["중립", "슬픔", "분노", "불안", "행복", "당황"]
def predict_with_prob(input_sentence):
    inputs = tokenizer(input_sentence, return_tensors="pt", max_length=75, padding=True, truncation=True)
    input_ids = inputs["input_ids"].to(device)
    attention_mask = inputs["attention_mask"].to(device)
    
    # 모델을 사용하여 감정 예측
    outputs = model(input_ids, attention_mask)
    logits = outputs.logits
    probs = torch.softmax(logits, dim=1)

    # 예측된 감정
    predicted_class_idx = torch.argmax(logits, dim=1).item()
    predicted_emotion = class_names[predicted_class_idx]

    # 각 클래스(감정)별 확률
    class_probs = probs.squeeze().tolist()

    # 결과 반환
    return predicted_emotion, class_probs

# %%
# 질문 무한반복하기! 0 입력시 종료
end = 1
while end == 1:
    sentence = input("하고싶은 말을 입력해주세요 : ")
    if sentence == "0":
        break
    print("입력한 문장:", sentence)
    
    # 감정 예측 및 각 클래스(감정)별 확률 출력
    predicted_emotion, class_probs = predict_with_prob(sentence)
    print("예측된 감정:", predicted_emotion)
    print("각 클래스별 확률:")
    for class_name, prob in zip(class_names, class_probs):
        print(f"{class_name}: {prob*100:.2f}%")
    print("\n")
# Out:
# 입력한 문장: 너무 슬프잖아...
# 예측된 감정: 슬픔
# 각 클래스별 확률:
# 중립: 6.78%
# 슬픔: 91.82%
# 분노: 0.26%
# 불안: 0.63%
# 행복: 0.29%
# 당황: 0.21%
